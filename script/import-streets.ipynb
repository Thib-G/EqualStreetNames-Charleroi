# %%
import json
import pandas as pd
import duckdb

# %%
with open('relation.json', 'r') as f:
    relation = json.loads(f.read())

# %%
with open('way.json', 'r') as f:
    way = json.loads(f.read())

# %%
[el.get('tags').get('name') for el in relation.get('elements') if el.get('tags', {}).get('name')]
# Out:
# ['Domaine Vieux Moulin',
#  "Rue de l'Abbaye",
#  'Rue de la Limite',
#  'Rue du 8 Mai',
#  'Place Verte']

# %%
names = [
    {
        'type': el.get('type'),
        'id': el.get('id'),
        'name': el.get('tags').get('name'),
        'gender': '',
        'person': '',
        'description': '',
    }
    for el in way.get('elements') if el.get('tags', {}).get('name')
]

# %%
df_way = pd.DataFrame(names)

# %%
df_prenoms = pd.read_csv('Prenoms.csv', sep=';')

# %%
df_prenom_clean = duckdb.sql("""
    SELECT
        *,
        REPLACE(REPLACE("01_prenom", ' (1)', ''), ' (2)', '') AS prenom
    FROM
        df_prenoms
    WHERE
        "01_prenom" NOT LIKE 'rue'
""").df()

# %%
df_prenoms_unique = duckdb.sql("""
    SELECT DISTINCT ON (prenom)
        *
    FROM
        df_prenom_clean
    WHERE
        prenom IS NOT NULL
    ORDER BY
        prenom,
        "04_fréquence" DESC
    
""").df()

# %%
df_prenoms_unique
# Out:
#       01_prenom 02_genre            03_langage  04_fréquence    prenom
# 0        'abbas        m                arabic           0.0    'abbas
# 1         'abla        f                arabic           0.0     'abla
# 2        'aisha        f                arabic           0.0    'aisha
# 3         'aziz        m                arabic           0.0     'aziz
# 4         'isam        m                arabic           0.0     'isam
# ...         ...      ...                   ...           ...       ...
# 11503  þórbjörn        m  ancient scandinavian           0.0  þórbjörn
# 11504    þórdís        f  ancient scandinavian           0.0    þórdís
# 11505     þórir        m             icelandic           0.0     þórir
# 11506      þórr        m       norse mythology           0.0      þórr
# 11507  þórstein        m  ancient scandinavian           0.0  þórstein
#
# [11508 rows x 5 columns]

# %%
df_genre = pd.DataFrame({'02_genre': ['m', 'f', 'f,m', 'm,f'], 'gender': ['M', 'F', 'F', 'M']})

# %%
df_final = duckdb.sql("""
    SELECT DISTINCT ON (w.id)
        w.type,
        w.id,
        w.name,
        g.gender,
        w.person,
        w.description,
        p.prenom,
        p."02_genre"
    FROM
        df_way AS w
    LEFT JOIN
        df_prenoms_unique AS p
        ON strip_accents(w.name) ILIKE '% ' || strip_accents(p.prenom) || ' %'
    LEFT JOIN
        df_genre AS g
        ON p."02_genre" = g."02_genre"
    ORDER BY
        w.id,
        p."04_fréquence" DESC
""").df()

# %%
df_final
# Out:
#       type          id                     name gender person description
# 0      way     4309822            Rue du Tilloi    NaN                     \
# 1      way     4309823          Rue du Muturnia    NaN
# 2      way     4309827  Grand Ring de Charleroi    NaN
# 3      way     4309829    Chaussée de Charleroi    NaN
# 4      way     4405030      Rue Dominique Seret      F
# ...    ...         ...                      ...    ...    ...         ...
# 10500  way  1173652014         Rue d'Heppignies    NaN
# 10501  way  1173968897         Sentier de Buzet    NaN
# 10502  way  1174678403            Rue du Cazier    NaN
# 10503  way  1175521590          Rue de Beaumont    NaN
# 10504  way  1175521591          Rue de Beaumont    NaN
#
#           prenom 02_genre
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4      dominique      f,m
# ...          ...      ...
# 10500        NaN      NaN
# 10501        NaN      NaN
# 10502        NaN      NaN
# 10503        NaN      NaN
# 10504        NaN      NaN
#
# [10505 rows x 8 columns]

# %%
df_final.to_csv('data.csv')
